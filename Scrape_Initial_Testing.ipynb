# %%
import pandas as pd

# %%
spark = pd.read_html('https://github.com/apache/spark')

# %%
# Out:
# [    Type                                       Name  \
#  0    NaN  Failed to load latest commit information.
#  1    NaN                                    .github
#  2    NaN                                          R
#  3    NaN                                   assembly
#  4    NaN                                        bin
#  5    NaN                                      build
#  6    NaN                                     common
#  7    NaN                                       conf
#  8    NaN                                       core
#  9    NaN                                       data
#  10   NaN                                        dev
#  11   NaN                                       docs
#  12   NaN                                   examples
#  13   NaN                                   external
#  14   NaN                                      graph
#  15   NaN                                     graphx
#  16   NaN                               hadoop-cloud
# ...

# %%
# Out:
#     Type                                       Name  \
# 0    NaN  Failed to load latest commit information.
# 1    NaN                                    .github
# 2    NaN                                          R
# 3    NaN                                   assembly
# 4    NaN                                        bin
# 5    NaN                                      build
# 6    NaN                                     common
# 7    NaN                                       conf
# 8    NaN                                       core
# 9    NaN                                       data
# 10   NaN                                        dev
# 11   NaN                                       docs
# 12   NaN                                   examples
# 13   NaN                                   external
# 14   NaN                                      graph
# 15   NaN                                     graphx
# 16   NaN                               hadoop-cloud
# ...
