# %%
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %matplotlib inline
import matplotlib.pyplot as plt

import seaborn as sns

# %%
agglo = pd.read_csv('remodularization_input_30_affinity.csv')

# %%
agglo = agglo[['Instance', 'abstractMethods_max', 
               'abstractMethods_mean', 
               'defaultMethods_sum', 
               'anonymousClassesQty_sum', 
               'cbo_max', 
               'cbo_sum',
               'comparisonsQty_max',
               'defaultMethods_max',
               'cbo_mean',
               'Label']]

labels = ['cosine', 'euclidean', 'l1', 'l2']

agglo = agglo.loc[agglo['Label'].isin(labels)]

# %%
agglo.head(100)
# Out:
#                         Instance  abstractMethods_max  abstractMethods_mean  \
# 0             apache-storm_1.1.1                   12                    12
# 1             apache-storm_1.1.2                   12                    12
# 2             apache-storm_1.1.3                   12                    12
# 3             apache-storm_1.1.4                   12                    12
# 4             apache-storm_1.2.0                   12                    12
# 5             apache-storm_1.2.1                   12                    12
# 6             apache-storm_1.2.2                   12                    12
# 7             apache-storm_1.2.3                   12                    12
# 8             apache-storm_2.0.0                   14                    14
# 9        apache-cassandra_3.11.4                   18                    18
# 10          apache-cassandra_3.2                   15                    15
# ...

# %%
agglo.to_csv('remodularization_input_30_grouped_affinity.csv', index=False)
