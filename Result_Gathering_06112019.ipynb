# %%
import json
import pandas as pd
import numpy as np
import networkx as nx
import os
import shutil
import subprocess
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn import preprocessing
from sklearn.cluster import AgglomerativeClustering

# %%
def read_dataframe_from_file(filename, filesubstr):
    
    final_results = []
    initial_line = 2 - 1
    initial_line_result = 5 - 1
    
    num_class_f = open('Final_Results/' + filesubstr + '/num_class.txt')
    for line in num_class_f:
        num_class = line
        
    #print(num_class)

    f = open(filename, 'r')
    tmp_arr = []
    for i, line in enumerate(f):
        if i == initial_line:
            line = line.replace('MoJo', '')
            line = line.replace('.rsf', '')
            line = line.replace('(', '')
            line = line.replace(')', '')
            line = line.split('_')
            name = line[0].split('/')[0]
            version = line[0].split('-')[-1]
            n_cluster = line[1]
            affinity = line[2]
            linkage = line[3]
            #print(line)
            #print('Version', version)
            initial_line += 5
            tmp_arr.append(name)
            tmp_arr.append(version)
            tmp_arr.append(n_cluster)
            tmp_arr.append(affinity)
            tmp_arr.append(linkage)
        elif i == initial_line_result:
            n_MoJo = line.split(' ')[-1].split('\n')[0]
            
            #print(line)
            initial_line_result += 5
            tmp_arr.append(n_MoJo)
            tmp_arr.append((1 - (float(n_MoJo) / float(num_class))) * 100)
            final_results.append(tmp_arr)
            tmp_arr = []
            
    
    
    f.close()
    return final_results


def read_bunch_dataframe_from_file(filename, filesubstr):
    
    final_results = []
    initial_line = 2 - 1
    initial_line_result = 5 - 1
    
    num_class_f = open('Final_Results/' + filesubstr + '/num_class.txt')
    for line in num_class_f:
        num_class = line
        
    #print(num_class)

    f = open(filename, 'r')
    tmp_arr = []
    for i, line in enumerate(f):
        try:
            if i == initial_line:
                line = line.replace('MoJo', '')
                line = line.replace('.rsf', '')
                line = line.replace('(', '')
                line = line.replace(')', '')
                line = line.split('_')
                name = line[0].split('/')[0]
                version = line[0].split('-')[-1]
                bunch_algo = line[1]
                #print(line)
                #print('Version', version)
                initial_line += 5
                tmp_arr.append(name)
                tmp_arr.append(version)
                tmp_arr.append(bunch_algo)
            elif i == initial_line_result:
                n_MoJo = line.split(' ')[-1].split('\n')[0]

                #print(line)
                initial_line_result += 5
                tmp_arr.append(n_MoJo)
                tmp_arr.append((1 - (float(n_MoJo) / float(num_class))) * 100)
                final_results.append(tmp_arr)
                tmp_arr = []
        except:
            pass
    
    
    f.close()
    return final_results

# %%
# Getting the smallest MoJo Value
rootdir = 'Final_Results/'
project_names = []

f = open('project_list.txt', 'r')
for line in f:
    print(line)
    project_names.append(line.split('\n')[0])

#project_names = ['apache-maven', 'apache-storm']
dir_arr = []

#Main clustering arr to be transformed to pandas dataframe later
cluster_main_arr = []

#Main CK arr to be transformed to pandas dataframe later
ck_sum_arr = []
ck_max_arr = []
ck_std_arr = []
ck_mean_arr = []

# Only considering the below ck_metrics
ck_metrics = ['cbo', 'wmc', 'dit', 'rfc', 'lcom',
       'totalMethods', 'staticMethods', 'publicMethods', 'privateMethods',
       'protectedMethods', 'defaultMethods', 'abstractMethods', 'finalMethods',
       'synchronizedMethods', 'totalFields', 'staticFields', 'publicFields',
       'privateFields', 'protectedFields', 'defaultFields', 'finalFields',
       'synchronizedFields', 'nosi', 'loc', 'returnQty', 'loopQty',
       'comparisonsQty', 'tryCatchQty', 'parenthesizedExpsQty',
       'stringLiteralsQty', 'numbersQty', 'assignmentsQty',
       'mathOperationsQty', 'variablesQty', 'maxNestedBlocks',
       'anonymousClassesQty', 'subClassesQty', 'lambdasQty', 'uniqueWordsQty',
       'modifiers']

depth = 3
for project_name in project_names:
    rootdir += project_name
    #print(rootdir)
    for root, dirs, files in os.walk(rootdir):
        for file in files:
            
            dir_arr.append(rootdir + '/' + str(file))
    rootdir = 'Final_Results/'
            
for element in dir_arr:
    ver = str(element).replace('_class.csv', '')
    ver = ver.split('-')[-1]

    if '_class.csv' in element:
        """
        df_sum = pd.read_csv(element)
        current_element_sum = df_sum.sum()

        df_max = pd.read_csv(element)
        current_element_max = df_max.max()

        df_std = pd.read_csv(element)
        current_element_std = df_std.std()

        df_mean = pd.read_csv(element)
        current_element_mean = df_mean.mean()

        tmp_sum = []
        tmp_max = []
        tmp_std = []
        tmp_mean = []

        tmp_sum.append(project_name)
        tmp_sum.append(ver)

        tmp_max.append(project_name)
        tmp_max.append(ver)

        tmp_std.append(project_name)
        tmp_std.append(ver)

        tmp_mean.append(project_name)
        tmp_mean.append(ver)

        for element in ck_metrics:
            tmp_sum.append(current_element_sum[element])
            tmp_max.append(current_element_max[element])
            tmp_std.append(current_element_std[element])
            tmp_mean.append(current_element_mean[element])

        ck_sum_arr.append(tmp_sum)
        ck_max_arr.append(tmp_max)
        ck_std_arr.append(tmp_std)
        ck_mean_arr.append(tmp_mean)
        """

    elif '_results.txt' in element:
        
        project_name = element.split('/')[1]
        print(project_name, element)
        spark_df = pd.DataFrame(read_dataframe_from_file(element, project_name))
        spark_df.columns = ['name', 'version', 'n_clusters', 'affinity', 'linkage', 'n_MoJo', 'mojoFM']
        #spark_df['mojoFM'] = (1 - spark_df['n_MoJo'].astype(int)/spark_count)*100
        #print(spark_df[spark_df.n_MoJo == spark_df.n_MoJo.min()].iloc[0])
        #print(spark_df.loc[spark_df.groupby('version').mojoFM.idxmax()].reset_index(drop=True))
        for element in spark_df.loc[spark_df.groupby('version').mojoFM.idxmax()].reset_index(drop=True).iterrows():
            tmp_arr2 = []
            tmp_arr2.append(element[1]['name'])
            tmp_arr2.append(element[1]['version'])
            tmp_arr2.append(element[1]['n_clusters'])
            tmp_arr2.append(element[1]['affinity'])
            tmp_arr2.append(element[1]['linkage'])
            tmp_arr2.append(element[1]['n_MoJo'])
            tmp_arr2.append(element[1]['mojoFM'])

            cluster_main_arr.append(tmp_arr2)
#cluster_main_arr.append(spark_df.loc[spark_df.groupby('version').mojoFM.idxmax()].reset_index(drop=True))
        #cluster_main_arr.append(spark_df[spark_df.n_MoJo == spark_df.n_MoJo.min()].iloc[0])


#dir_arr = []
# Out:
# apache-storm
#
# apache-cassandra
#
# airbnb-lottie-android
#
# apache-isis
#
# apache-jmeter
#
# apache-log4j
#
# apache-maven
#
# apache-spark
#
# apache-tomcat
#
# rzwitserloot-lombok
#
# apache-tika
#
# alibaba-fastjson
#
# activiti-activiti
#
# bumptech-glide
#
# codecentric-spring-boot-admin
#
# dropwizard-dropwizard
#
# dropwizard-metrics
#
# facebook-facebook-android-sdk
#
# google-dagger
#
# google-error-prone
#
# grpc-grpc-java
#
# java-native-accessjna
#
# jenkinsci-jenkins
#
# jhy-jsoup
#
# mockito-mockito
#
# mybatis-mybatis-3
#
# naver-pinpoint
#
# pxb1988-dex2jar
#
# ReactiveX-RxJava
#
# redisson-redisson
#
# swagger-api-swagger-core
#
# apache-accumulo
#
# apache-activemq
#
# apache-archiva
#
# apache-avro
#
# apache-beam
#
# apache-bookkeeper
#
# apache-calcite
#
# scribejava-scribejava
#
# joelittlejohn-jsonschema2pojo
#
# robolectric-robolectric
#
# rest-assured-rest-assured
#
# mrniko-netty-socketio
#
# JodaOrg-joda-time
#
# hibernate-hibernate-orm
#
# springfox-springfox
#
# spring-projects-spring-security
#
# jankotek-mapdb
#
# bytedeco-javacpp
#
# testcontainers-testcontainers-java
#
# sofastack-sofa-rpc
#
# knowm-XChange
#
# hazelcast-hazelcast
#
# cryptomator-cryptomator
#
# btraceio-btrace
#
# auth0-java-jwt
#
# oblac-jodd
#
# javaparser-javaparser
#
# iSoron-uhabits
#
# oracle-opengrok
#
# lettuce-io-lettuce-core
#
# querydsl-querydsl
#
# Twitter4J-Twitter4J
#
# web3j-web3j
#
# ZieIony-Carbon
#
# immutables-immutables
#
# pmd-pmd
#
# ionic-team-capacitor
#
# cglib-cglib
#
# raphw-byte-buddy
#
# quarkusio-quarkus
#
# uber-NullAway
#
# coobird-thumbnailator
#
# crate-crate
#
# alibaba-jetcache
#
# apache-storm Final_Results/apache-storm/apache-storm_results.txt
# apache-cassandra Final_Results/apache-cassandra/apache-cassandra_results.txt
# airbnb-lottie-android Final_Results/airbnb-lottie-android/airbnb-lottie-android_results.txt
# apache-isis Final_Results/apache-isis/apache-isis_results.txt
# apache-jmeter Final_Results/apache-jmeter/apache-jmeter_results.txt
# apache-log4j Final_Results/apache-log4j/apache-log4j_results.txt
# apache-maven Final_Results/apache-maven/apache-maven_results.txt
# apache-spark Final_Results/apache-spark/apache-spark_results.txt
# apache-tomcat Final_Results/apache-tomcat/apache-tomcat_results.txt
# rzwitserloot-lombok Final_Results/rzwitserloot-lombok/rzwitserloot-lombok_results.txt
# apache-tika Final_Results/apache-tika/apache-tika_results.txt
# alibaba-fastjson Final_Results/alibaba-fastjson/alibaba-fastjson_results.txt
# activiti-activiti Final_Results/activiti-activiti/activiti-activiti_results.txt
# bumptech-glide Final_Results/bumptech-glide/bumptech-glide_results.txt
# codecentric-spring-boot-admin Final_Results/codecentric-spring-boot-admin/codecentric-spring-boot-admin_results.txt
# dropwizard-dropwizard Final_Results/dropwizard-dropwizard/dropwizard-dropwizard_results.txt
# dropwizard-metrics Final_Results/dropwizard-metrics/dropwizard-metrics_results.txt
# facebook-facebook-android-sdk Final_Results/facebook-facebook-android-sdk/facebook-facebook-android-sdk_results.txt
# google-dagger Final_Results/google-dagger/google-dagger_results.txt
# google-error-prone Final_Results/google-error-prone/google-error-prone_results.txt
# grpc-grpc-java Final_Results/grpc-grpc-java/grpc-grpc-java_results.txt
# java-native-accessjna Final_Results/java-native-accessjna/java-native-accessjna_results.txt
# jenkinsci-jenkins Final_Results/jenkinsci-jenkins/jenkinsci-jenkins_results.txt
# jhy-jsoup Final_Results/jhy-jsoup/jhy-jsoup_results.txt
# mockito-mockito Final_Results/mockito-mockito/mockito-mockito_results.txt
# mybatis-mybatis-3 Final_Results/mybatis-mybatis-3/mybatis-mybatis-3_results.txt
# naver-pinpoint Final_Results/naver-pinpoint/naver-pinpoint_results.txt
# pxb1988-dex2jar Final_Results/pxb1988-dex2jar/pxb1988-dex2jar_results.txt
# ReactiveX-RxJava Final_Results/ReactiveX-RxJava/ReactiveX-RxJava_results.txt
# redisson-redisson Final_Results/redisson-redisson/redisson-redisson_results.txt
# swagger-api-swagger-core Final_Results/swagger-api-swagger-core/swagger-api-swagger-core_results.txt
# apache-accumulo Final_Results/apache-accumulo/apache-accumulo_results.txt
# apache-activemq Final_Results/apache-activemq/apache-activemq_results.txt
# apache-archiva Final_Results/apache-archiva/apache-archiva_results.txt
# apache-avro Final_Results/apache-avro/apache-avro_results.txt
# apache-beam Final_Results/apache-beam/apache-beam_results.txt
# apache-bookkeeper Final_Results/apache-bookkeeper/apache-bookkeeper_results.txt
# apache-calcite Final_Results/apache-calcite/apache-calcite_results.txt
# scribejava-scribejava Final_Results/scribejava-scribejava/scribejava-scribejava_results.txt
# joelittlejohn-jsonschema2pojo Final_Results/joelittlejohn-jsonschema2pojo/joelittlejohn-jsonschema2pojo_results.txt
# robolectric-robolectric Final_Results/robolectric-robolectric/robolectric-robolectric_results.txt
# rest-assured-rest-assured Final_Results/rest-assured-rest-assured/rest-assured-rest-assured_results.txt
# mrniko-netty-socketio Final_Results/mrniko-netty-socketio/mrniko-netty-socketio_results.txt
# JodaOrg-joda-time Final_Results/JodaOrg-joda-time/JodaOrg-joda-time_results.txt
# hibernate-hibernate-orm Final_Results/hibernate-hibernate-orm/hibernate-hibernate-orm_results.txt
# springfox-springfox Final_Results/springfox-springfox/springfox-springfox_results.txt
# spring-projects-spring-security Final_Results/spring-projects-spring-security/spring-projects-spring-security_results.txt
# jankotek-mapdb Final_Results/jankotek-mapdb/jankotek-mapdb_results.txt
# bytedeco-javacpp Final_Results/bytedeco-javacpp/bytedeco-javacpp_results.txt
# testcontainers-testcontainers-java Final_Results/testcontainers-testcontainers-java/testcontainers-testcontainers-java_results.txt
# sofastack-sofa-rpc Final_Results/sofastack-sofa-rpc/sofastack-sofa-rpc_results.txt
# knowm-XChange Final_Results/knowm-XChange/knowm-XChange_results.txt
# hazelcast-hazelcast Final_Results/hazelcast-hazelcast/hazelcast-hazelcast_results.txt
# cryptomator-cryptomator Final_Results/cryptomator-cryptomator/cryptomator-cryptomator_results.txt
# btraceio-btrace Final_Results/btraceio-btrace/btraceio-btrace_results.txt
# auth0-java-jwt Final_Results/auth0-java-jwt/auth0-java-jwt_results.txt
# oblac-jodd Final_Results/oblac-jodd/oblac-jodd_results.txt
# javaparser-javaparser Final_Results/javaparser-javaparser/javaparser-javaparser_results.txt
# iSoron-uhabits Final_Results/iSoron-uhabits/iSoron-uhabits_results.txt
# oracle-opengrok Final_Results/oracle-opengrok/oracle-opengrok_results.txt
# lettuce-io-lettuce-core Final_Results/lettuce-io-lettuce-core/lettuce-io-lettuce-core_results.txt
# querydsl-querydsl Final_Results/querydsl-querydsl/querydsl-querydsl_results.txt
# Twitter4J-Twitter4J Final_Results/Twitter4J-Twitter4J/Twitter4J-Twitter4J_results.txt
# web3j-web3j Final_Results/web3j-web3j/web3j-web3j_results.txt
# ZieIony-Carbon Final_Results/ZieIony-Carbon/ZieIony-Carbon_results.txt
# immutables-immutables Final_Results/immutables-immutables/immutables-immutables_results.txt
# pmd-pmd Final_Results/pmd-pmd/pmd-pmd_results.txt
# ionic-team-capacitor Final_Results/ionic-team-capacitor/ionic-team-capacitor_results.txt
# cglib-cglib Final_Results/cglib-cglib/cglib-cglib_results.txt
# raphw-byte-buddy Final_Results/raphw-byte-buddy/raphw-byte-buddy_results.txt
# quarkusio-quarkus Final_Results/quarkusio-quarkus/quarkusio-quarkus_results.txt
# uber-NullAway Final_Results/uber-NullAway/uber-NullAway_results.txt
# coobird-thumbnailator Final_Results/coobird-thumbnailator/coobird-thumbnailator_results.txt
# crate-crate Final_Results/crate-crate/crate-crate_results.txt
# alibaba-jetcache Final_Results/alibaba-jetcache/alibaba-jetcache_results.txt

# %%
final_clustering_result = pd.DataFrame(cluster_main_arr)
final_clustering_result.columns = ['name', 'version', 'n_clusters', 'affinity', 'linkage', 'n_MoJo', 'mojoFM']

# %%
final_clustering_result.head(30)
# Out:
#                      name version n_clusters   affinity   linkage n_MoJo  \
# 0            apache-storm   1.1.0        100         l2    single   1568
# 1            apache-storm   1.1.1         50  euclidean    single   1574
# 2            apache-storm   1.1.2         50     cosine    single    508
# 3            apache-storm   1.1.3         50     cosine    single    511
# 4            apache-storm   1.1.4         50     cosine    single    505
# 5            apache-storm   1.2.0         50     cosine    single    468
# 6            apache-storm   1.2.1         50     cosine    single    465
# 7            apache-storm   1.2.2         50     cosine    single    487
# 8            apache-storm   1.2.3         50     cosine    single    447
# 9            apache-storm   2.0.0         50     cosine    single   1907
# 10       apache-cassandra  3.11.3         50  euclidean    single    532
# 11       apache-cassandra  3.11.4         50  euclidean    single    554
# 12       apache-cassandra     3.2         50  euclidean    single    170
# 13       apache-cassandra   3.2.1         50  euclidean    single    170
# 14       apache-cassandra     3.3         50  euclidean    single    172
# 15       apache-cassandra     3.4         50  euclidean    single    291
# 16       apache-cassandra     3.5         50  euclidean    single    256
# 17       apache-cassandra     3.6         50  euclidean    single    297
# 18       apache-cassandra     3.7         50  euclidean    single    289
# 19       apache-cassandra     3.8         50  euclidean    single    328
# 20  airbnb-lottie-android   2.6.0        100         l2   average     72
# 21  airbnb-lottie-android   2.6.1        100         l2  complete     72
# 22  airbnb-lottie-android   2.7.0        100     cosine    single     69
# 23  airbnb-lottie-android   3.0.0        150  manhattan  complete     34
# 24  airbnb-lottie-android   3.0.1        150     cosine  complete     34
# 25  airbnb-lottie-android   3.0.2        150         l2  complete     38
# 26  airbnb-lottie-android   3.0.3        150         l2   average     36
# 27  airbnb-lottie-android   3.0.4        150         l1  complete     43
# 28  airbnb-lottie-android   3.0.5        150         l2  complete     43
# 29  airbnb-lottie-android   3.0.6        150  euclidean  complete     40
#
#        mojoFM
# 0   23.698297
# 1   23.406326
# 2   75.279805
# 3   75.133820
# 4   75.425791
# 5   77.226277
# 6   77.372263
# 7   76.301703
# 8   78.248175
# 9    7.201946
# 10  77.684564
# 11  76.761745
# 12  92.869128
# 13  92.869128
# 14  92.785235
# 15  87.793624
# 16  89.261745
# 17  87.541946
# 18  87.877517
# 19  86.241611
# 20  90.476190
# 21  90.476190
# 22  90.873016
# 23  95.502646
# 24  95.502646
# 25  94.973545
# 26  95.238095
# 27  94.312169
# 28  94.312169
# 29  94.708995

# %%
final_clustering_result = final_clustering_result.dropna()
final_clustering_result.to_csv('agglo_clustering_result_75_ver.csv', index=False)

# %% [markdown]
# ## Getting Bunch Result

# %%
# Getting the smallest MoJo Value
rootdir = 'Final_Results_Bunch/'
project_names = []
dir_arr = []

f = open('project_list.txt', 'r')
for line in f:
    #print(line)
    project_names.append(line.split('\n')[0])

f.close()
cluster_main_arr_bunch = []

depth = 3
for project_name in project_names:
    rootdir += project_name
    #print(rootdir)
    for root, dirs, files in os.walk(rootdir):
        for file in files:
            
            dir_arr.append(rootdir + '/' + str(file))
    rootdir = 'Final_Results_Bunch/'
    
for element in dir_arr:

    #print(element)
    project_name = element.split('/')[1]
    if '_results_bunch.txt' in element:
        print(project_name, element)

        spark_df = pd.DataFrame(read_bunch_dataframe_from_file(element, project_name))
        spark_df.columns = ['name', 'version', 'bunch_algo', 'n_MoJo', 'mojoFM']
        #spark_df['mojoFM'] = (1 - spark_df['n_MoJo'].astype(int)/spark_count)*100
        #print(spark_df[spark_df.n_MoJo == spark_df.n_MoJo.min()].iloc[0])
        #print(spark_df.loc[spark_df.groupby('version').mojoFM.idxmax()].reset_index(drop=True))

        try:
            for element in spark_df.loc[spark_df.groupby(['name','version']).mojoFM.idxmax()].reset_index(drop=True).iterrows():
                tmp_arr2 = []
                tmp_arr2.append(element[1]['name'])
                tmp_arr2.append(element[1]['version'])
                tmp_arr2.append(element[1]['bunch_algo'])
                tmp_arr2.append(element[1]['n_MoJo'])
                tmp_arr2.append(element[1]['mojoFM'])

                cluster_main_arr_bunch.append(tmp_arr2)
        except:
            print(element)
    #cluster_main_arr.append(spark_df.loc[spark_df.groupby('version').mojoFM.idxmax()].reset_index(drop=True))
            #cluster_main_arr.append(spark_df[spark_df.n_MoJo == spark_df.n_MoJo.min()].iloc[0])
    
    
    #dir_arr = []
# Out:
# apache-storm Final_Results_Bunch/apache-storm/apache-storm_results_bunch.txt
# apache-cassandra Final_Results_Bunch/apache-cassandra/apache-cassandra_results_bunch.txt
# airbnb-lottie-android Final_Results_Bunch/airbnb-lottie-android/airbnb-lottie-android_results_bunch.txt
# apache-isis Final_Results_Bunch/apache-isis/apache-isis_results_bunch.txt
# apache-jmeter Final_Results_Bunch/apache-jmeter/apache-jmeter_results_bunch.txt
# apache-log4j Final_Results_Bunch/apache-log4j/apache-log4j_results_bunch.txt
# apache-maven Final_Results_Bunch/apache-maven/apache-maven_results_bunch.txt
# apache-spark Final_Results_Bunch/apache-spark/apache-spark_results_bunch.txt
# apache-tomcat Final_Results_Bunch/apache-tomcat/apache-tomcat_results_bunch.txt
# rzwitserloot-lombok Final_Results_Bunch/rzwitserloot-lombok/rzwitserloot-lombok_results_bunch.txt
# apache-tika Final_Results_Bunch/apache-tika/apache-tika_results_bunch.txt
# alibaba-fastjson Final_Results_Bunch/alibaba-fastjson/alibaba-fastjson_results_bunch.txt
# activiti-activiti Final_Results_Bunch/activiti-activiti/activiti-activiti_results_bunch.txt
# bumptech-glide Final_Results_Bunch/bumptech-glide/bumptech-glide_results_bunch.txt
# codecentric-spring-boot-admin Final_Results_Bunch/codecentric-spring-boot-admin/codecentric-spring-boot-admin_results_bunch.txt
# dropwizard-dropwizard Final_Results_Bunch/dropwizard-dropwizard/dropwizard-dropwizard_results_bunch.txt
# dropwizard-metrics Final_Results_Bunch/dropwizard-metrics/dropwizard-metrics_results_bunch.txt
# facebook-facebook-android-sdk Final_Results_Bunch/facebook-facebook-android-sdk/facebook-facebook-android-sdk_results_bunch.txt
# google-dagger Final_Results_Bunch/google-dagger/google-dagger_results_bunch.txt
# google-error-prone Final_Results_Bunch/google-error-prone/google-error-prone_results_bunch.txt
# grpc-grpc-java Final_Results_Bunch/grpc-grpc-java/grpc-grpc-java_results_bunch.txt
# java-native-accessjna Final_Results_Bunch/java-native-accessjna/java-native-accessjna_results_bunch.txt
# jenkinsci-jenkins Final_Results_Bunch/jenkinsci-jenkins/jenkinsci-jenkins_results_bunch.txt
# jhy-jsoup Final_Results_Bunch/jhy-jsoup/jhy-jsoup_results_bunch.txt
# mockito-mockito Final_Results_Bunch/mockito-mockito/mockito-mockito_results_bunch.txt
# mybatis-mybatis-3 Final_Results_Bunch/mybatis-mybatis-3/mybatis-mybatis-3_results_bunch.txt
# naver-pinpoint Final_Results_Bunch/naver-pinpoint/naver-pinpoint_results_bunch.txt
# pxb1988-dex2jar Final_Results_Bunch/pxb1988-dex2jar/pxb1988-dex2jar_results_bunch.txt
# ReactiveX-RxJava Final_Results_Bunch/ReactiveX-RxJava/ReactiveX-RxJava_results_bunch.txt
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# redisson-redisson Final_Results_Bunch/redisson-redisson/redisson-redisson_results_bunch.txt
# swagger-api-swagger-core Final_Results_Bunch/swagger-api-swagger-core/swagger-api-swagger-core_results_bunch.txt
# hibernate-hibernate-orm Final_Results_Bunch/hibernate-hibernate-orm/hibernate-hibernate-orm_results_bunch.txt
# springfox-springfox Final_Results_Bunch/springfox-springfox/springfox-springfox_results_bunch.txt
# spring-projects-spring-security Final_Results_Bunch/spring-projects-spring-security/spring-projects-spring-security_results_bunch.txt
# jankotek-mapdb Final_Results_Bunch/jankotek-mapdb/jankotek-mapdb_results_bunch.txt
# bytedeco-javacpp Final_Results_Bunch/bytedeco-javacpp/bytedeco-javacpp_results_bunch.txt
# testcontainers-testcontainers-java Final_Results_Bunch/testcontainers-testcontainers-java/testcontainers-testcontainers-java_results_bunch.txt
# sofastack-sofa-rpc Final_Results_Bunch/sofastack-sofa-rpc/sofastack-sofa-rpc_results_bunch.txt
# knowm-XChange Final_Results_Bunch/knowm-XChange/knowm-XChange_results_bunch.txt
# hazelcast-hazelcast Final_Results_Bunch/hazelcast-hazelcast/hazelcast-hazelcast_results_bunch.txt
# cryptomator-cryptomator Final_Results_Bunch/cryptomator-cryptomator/cryptomator-cryptomator_results_bunch.txt
# btraceio-btrace Final_Results_Bunch/btraceio-btrace/btraceio-btrace_results_bunch.txt
# auth0-java-jwt Final_Results_Bunch/auth0-java-jwt/auth0-java-jwt_results_bunch.txt
# oblac-jodd Final_Results_Bunch/oblac-jodd/oblac-jodd_results_bunch.txt
# javaparser-javaparser Final_Results_Bunch/javaparser-javaparser/javaparser-javaparser_results_bunch.txt
# iSoron-uhabits Final_Results_Bunch/iSoron-uhabits/iSoron-uhabits_results_bunch.txt
# oracle-opengrok Final_Results_Bunch/oracle-opengrok/oracle-opengrok_results_bunch.txt
# lettuce-io-lettuce-core Final_Results_Bunch/lettuce-io-lettuce-core/lettuce-io-lettuce-core_results_bunch.txt
# querydsl-querydsl Final_Results_Bunch/querydsl-querydsl/querydsl-querydsl_results_bunch.txt
# Twitter4J-Twitter4J Final_Results_Bunch/Twitter4J-Twitter4J/Twitter4J-Twitter4J_results_bunch.txt
# web3j-web3j Final_Results_Bunch/web3j-web3j/web3j-web3j_results_bunch.txt
# ZieIony-Carbon Final_Results_Bunch/ZieIony-Carbon/ZieIony-Carbon_results_bunch.txt
# immutables-immutables Final_Results_Bunch/immutables-immutables/immutables-immutables_results_bunch.txt
# pmd-pmd Final_Results_Bunch/pmd-pmd/pmd-pmd_results_bunch.txt
# ionic-team-capacitor Final_Results_Bunch/ionic-team-capacitor/ionic-team-capacitor_results_bunch.txt
# cglib-cglib Final_Results_Bunch/cglib-cglib/cglib-cglib_results_bunch.txt
# raphw-byte-buddy Final_Results_Bunch/raphw-byte-buddy/raphw-byte-buddy_results_bunch.txt
# quarkusio-quarkus Final_Results_Bunch/quarkusio-quarkus/quarkusio-quarkus_results_bunch.txt
# uber-NullAway Final_Results_Bunch/uber-NullAway/uber-NullAway_results_bunch.txt
# coobird-thumbnailator Final_Results_Bunch/coobird-thumbnailator/coobird-thumbnailator_results_bunch.txt
# crate-crate Final_Results_Bunch/crate-crate/crate-crate_results_bunch.txt
# alibaba-jetcache Final_Results_Bunch/alibaba-jetcache/alibaba-jetcache_results_bunch.txt

# %%
#print(cluster_main_arr_bunch)
final_clustering_result_bunch = pd.DataFrame(cluster_main_arr_bunch)
final_clustering_result_bunch.columns = ['name', 'version', 'bunch_algo', 'n_MoJo', 'mojoFM']
final_clustering_result_bunch = final_clustering_result_bunch.dropna()
print(len(final_clustering_result_bunch['name'].unique()))
print(final_clustering_result_bunch['name'].unique())
final_clustering_result_bunch.head(30)
# Out:
# 62
# ['apache-storm' 'apache-cassandra' 'airbnb-lottie-android' 'apache-isis'
#  'apache-jmeter' 'apache-log4j' 'apache-maven' 'apache-spark'
#  'apache-tomcat' 'rzwitserloot-lombok' 'apache-tika' 'alibaba-fastjson'
#  'activiti-activiti' 'bumptech-glide' 'codecentric-spring-boot-admin'
#  'dropwizard-dropwizard' 'dropwizard-metrics'
#  'facebook-facebook-android-sdk' 'google-dagger' 'google-error-prone'
#  'grpc-grpc-java' 'java-native-accessjna' 'jenkinsci-jenkins' 'jhy-jsoup'
#  'mockito-mockito' 'mybatis-mybatis-3' 'naver-pinpoint' 'pxb1988-dex2jar'
#  'ReactiveX-RxJava' 'redisson-redisson' 'swagger-api-swagger-core'
#  'hibernate-hibernate-orm' 'springfox-springfox'
#  'spring-projects-spring-security' 'jankotek-mapdb' 'bytedeco-javacpp'
#  'testcontainers-testcontainers-java' 'sofastack-sofa-rpc' 'knowm-XChange'
#  'hazelcast-hazelcast' 'cryptomator-cryptomator' 'btraceio-btrace'
#  'auth0-java-jwt' 'oblac-jodd' 'javaparser-javaparser' 'iSoron-uhabits'
#  'oracle-opengrok' 'lettuce-io-lettuce-core' 'querydsl-querydsl'
#  'Twitter4J-Twitter4J' 'web3j-web3j' 'ZieIony-Carbon'
#  'immutables-immutables' 'pmd-pmd' 'ionic-team-capacitor' 'cglib-cglib'
#  'raphw-byte-buddy' 'quarkusio-quarkus' 'uber-NullAway'
#  'coobird-thumbnailator' 'crate-crate' 'alibaba-jetcache']
#                      name version    bunch_algo n_MoJo     mojoFM
# 0            apache-storm   1.1.0            ga   1632  20.583942
# 1            apache-storm   1.1.1  hillclimbing   1693  17.615572
# 2            apache-storm   1.1.2  hillclimbing   1224  40.437956
# 3            apache-storm   1.1.3            ga   1290  37.226277
# 4            apache-storm   1.1.4            ga   1495  27.250608
# 5            apache-storm   1.2.0  hillclimbing   1595  22.384428
# 6            apache-storm   1.2.1  hillclimbing    847  58.783455
# 7            apache-storm   1.2.2    exhaustive   1518  26.131387
# 8            apache-storm   1.2.3  hillclimbing   1195  41.849148
# 9            apache-storm   2.0.0            ga   2219  -7.980535
# 10       apache-cassandra  3.11.3            ga   1718  27.936242
# 11       apache-cassandra  3.11.4  hillclimbing   1840  22.818792
# 12       apache-cassandra     3.2    exhaustive   1121  52.978188
# 13       apache-cassandra   3.2.1            ga   1444  39.429530
# 14       apache-cassandra     3.3            ga   1180  50.503356
# 15       apache-cassandra     3.4  hillclimbing   1628  31.711409
# 16       apache-cassandra     3.5    exhaustive   1606  32.634228
# 17       apache-cassandra     3.6    exhaustive   1501  37.038591
# 18       apache-cassandra     3.7    exhaustive   1544  35.234899
# 19       apache-cassandra     3.8  hillclimbing   1371  42.491611
# 20  airbnb-lottie-android   2.6.0  hillclimbing    113  85.052910
# 21  airbnb-lottie-android   2.6.1  hillclimbing    119  84.259259
# 22  airbnb-lottie-android   2.7.0            ga    111  85.317460
# 23  airbnb-lottie-android   3.0.0    exhaustive    118  84.391534
# 24  airbnb-lottie-android   3.0.1  hillclimbing    110  85.449735
# 25  airbnb-lottie-android   3.0.2    exhaustive    116  84.656085
# 26  airbnb-lottie-android   3.0.3    exhaustive     89  88.227513
# 27  airbnb-lottie-android   3.0.4    exhaustive     91  87.962963
# 28  airbnb-lottie-android   3.0.5  hillclimbing    126  83.333333
# 29  airbnb-lottie-android   3.0.6    exhaustive    113  85.052910

# %%
final_clustering_result_bunch.to_csv('bunch_clustering_result_62_ver.csv', index=False)
